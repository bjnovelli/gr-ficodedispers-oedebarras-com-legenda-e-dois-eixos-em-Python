# %% [markdown]
# <a href="https://colab.research.google.com/github/bjnovelli/gr-ficodedispers-oedebarras-com-legenda-e-dois-eixos-em-Python/blob/main/%20Gr%C3%A1fico%20de%20dispers%C3%A3o%20e%20de%20barras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 14})

# %%
x=np.arange (5)

# %%
array=([0,1,2.3,4])

# %%
y1 = np.random.uniform (0,10,len(x))
y1
# Out:
# array([1.7728334 , 7.46927797, 8.26686901, 7.6566866 , 4.13104951])

# %%
y1= np.sort(y1)
y1
# Out:
# array([1.7728334 , 4.13104951, 7.46927797, 7.6566866 , 8.26686901])

# %%
y2= np.random.uniform(10,100,len(x))
y2
# Out:
# array([27.3094524 , 59.38004097, 24.26957369, 57.51364217, 21.79630468])

# %%
fig,ax1=plt.subplots()
ax1.set_xlabel('X')
ax1.set_ylabel('$Y_1$',color='red')
ax1.tick_params(axis='y',labelcolor='red')
ax1.plot(x,y1)
ax1.plot(x,y1,marker='s',markersize=6,color='red',linestyle='--',label='y1')
ax1.set_ylim([0,10])



ax2=ax1.twinx()
ax2.set_ylabel('$Y_2$', color ='green')
ax2.tick_params(axis='y',labelcolor='green')
ax2.bar(x,y2,color='green',alpha=0.5,edgecolor='black',linewidth=2,label='y2')
ax2.set_ylim([0,100])
ax2.set_ylim([0,120])

ax1.legend(frameon=False)
ax2.legend(loc=2,frameon=False)

plt.savefig('Plot.final.png' , dpi=600)
